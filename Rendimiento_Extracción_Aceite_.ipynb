# %% [markdown]
# <a href="https://colab.research.google.com/github/ramirezberteldaniela-jpg/Notebooks_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE).** El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$ pa = lt * 0.92$$
#
# $$ r =(pa/pr) * 100$$
#
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
#Solicitar el peso de los racimos en kg (Tipo float). (pr)
#Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("ingrese el nombre del lote")
pr = float(input("ingrese el peso de los racimos"))
lt = float(input("ingrese los litros de aceite crudo obtenido en litros"))

# PROCESO:calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa/pr) * 100

# SALIDA:informar el rendimiento del lote
print("el rendimiento del lote", nombre, "es del", r, "%")
# Out:
# ingrese el nombre del loteel perico
# ingrese el peso de los racimos1000
# ingrese los litros de aceite crudo obtenido en litros200
# el rendimiento del lote el perico  es del 18.4 %

# %% [markdown]
# ```markdown
# ## Explicación del Código de Control de Rendimiento en Extracción de Aceite
#
# El siguiente código Python calcula el Índice de Rendimiento de Extracción (IRE) de aceite de palma, solicitando al usuario datos específicos y realizando los cálculos necesarios para finalmente mostrar el resultado.
#
# ### Desglose Línea por Línea:
#
# ```python
# # ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
# #Solicitar el peso de los racimos en kg (Tipo float). (pr)
# #Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios (`#`) que sirven para documentar el código. Indican qué tipo de datos se solicitan al usuario en la sección de entrada del programa (nombre del lote como string, peso de los racimos como float y litros de aceite como float).
#
# ```python
# nombre = input("ingrese el nombre del lote")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` muestra el mensaje entre paréntesis al usuario y espera su entrada. El valor ingresado, que es de tipo `string` por defecto, se almacena en la variable `nombre`.
#
# ```python
# pr = float(input("ingrese el peso de los racimos"))
# ```
# Aquí se pide al usuario el peso total de los racimos de fruta fresca (RFF) en kilogramos. La función `input()` obtiene el texto del usuario. Luego, `float()` convierte ese texto a un número decimal (tipo `float`), que es apropiado para representar pesos. El resultado se guarda en la variable `pr` (peso de racimos).
#
# ```python
# lt = float(input("ingrese los litros de aceite crudo obtenido en litros"))
# ```
# De manera similar a la línea anterior, esta línea solicita la cantidad de aceite crudo obtenida en litros. La entrada del usuario se convierte a un número decimal (`float`) usando `float()` y se almacena en la variable `lt` (litros de aceite).
#
# ```python
# # PROCESO:calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Otro comentario, esta vez indicando que las siguientes líneas realizarán los cálculos principales del programa: el peso del aceite y el rendimiento.
#
# ```python
# pa = lt * 0.92
# ```
# Esta línea calcula el peso aproximado del aceite (`pa`) en kilogramos. Para ello, multiplica los litros de aceite obtenidos (`lt`) por la densidad aproximada del aceite, que es 0.92 kg/L. El resultado se almacena en `pa` (peso de aceite).
#
# ```python
# r = (pa/pr) * 100
# ```
# Aquí se calcula el Índice de Rendimiento de Extracción (`r`). Se divide el peso del aceite (`pa`) entre el peso de los racimos (`pr`) y el resultado se multiplica por 100 para expresarlo como un porcentaje. Este valor representa el rendimiento y se guarda en la variable `r`.
#
# ```python
# # SALIDA:informar el rendimiento del lote
# ```
# Un comentario que señala que la siguiente línea se encargará de mostrar el resultado final al usuario.
#
# ```python
# print("el rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta es la línea de salida. La función `print()` muestra un mensaje en la consola. Concatena varias cadenas de texto y las variables `nombre` y `r` para formar una frase informativa que le indica al usuario el rendimiento del lote de producción específico.
